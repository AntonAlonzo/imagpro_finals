# %% [markdown]
# # **Plate Number Recognition System using Robinsons Compass Mask Edge Detection | Test Document**
# **IMAGPRO**
#
# ALONZO, Jose Anton S.
#
# HERNANDEZ, Pierre Vincent C.
#
# SOLIS, Frances Danielle B.
#
# SUSADA, Stephanie R.

# %% [markdown]
# ### *Import necessary header files or libraries*

# %%
import rcm
import format
import numpy as np
import glob
import cv2 as cv
import matplotlib.pyplot as plt

import string

# import video

#from ultralytics import YOLO

# %% [markdown]
# ## ***PHASE 1: Edge Detection***

# %% [markdown]
# First, read the image data and convert it to grayscale in preparation for the edge detection process

# %%
    # !!! CONFIGURE IMAGE FILE PARAMETERS HERE !!!
    img_name = "plate1"
    img_ext = ".png"
    img_path = "input/" + img_name + img_ext

    # Get grayscale version of the image
    img_raw = cv.imread(img_path)
    img_data = cv.cvtColor(img_raw, cv.COLOR_BGR2GRAY)
    plt.imshow(img_data, cmap='gray')

# %%
rcm.createDirectories(img_name)
# Out:
# RCM folder for compasses\plate1 data already exists
# Output folder for output\plate1 data already exists

# %% [markdown]
# Finalize the edge detection process

# %%
edged_img = rcm.detectEdgeAbs(img_data, img_name)
plt.imshow(edged_img, cmap="gray")
# Out:
# Generated array file: compasses\plate1\plate1_rcm_outputs.npy
# Generated image: compasses\plate1\plate1_E.png
# Generated image: compasses\plate1\plate1_SE.png
# Generated image: compasses\plate1\plate1_S.png
# Generated image: compasses\plate1\plate1_SW.png
# Generated image: compasses\plate1\plate1_W.png
# Generated image: compasses\plate1\plate1_NW.png
# Generated image: compasses\plate1\plate1_N.png
# Generated image: compasses\plate1\plate1_NE.png
# Generated array file: output\plate1\plate1_final_output.npy
# Generated image: output\plate1\plate1_final_output.png

# %%
edged_img = rcm.detectEdgeMax(img_data, img_name)
plt.imshow(edged_img, cmap="gray")
# Out:
# Generated array file: output\plate1\plate1_final_output.npy
# Generated image: output\plate1\plate1_final_output.png

# %% [markdown]
# ## ***PHASE 2: Process Images***

# %%
license_plate_text, license_plate_text_score = format.read_license_plate(edged_img)

# results = {}

# if license_plate_text is not None:
#     results[frame_nmr][car_id] = {'car': {'bbox': [xcar1, ycar1, xcar2, ycar2]},
#                                   'license_plate': {'bbox': [x1, y1, x2, y2],
#                                                     'text': license_plate_text,
#                                                     'bbox_score': score,
#                                                     'text_score': license_plate_text_score}}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26972\2602490140.py in <module>
# ----> 1 license_plate_text, license_plate_text_score = format.read_license_plate(edged_img)
#       2
#       3 # results = {}
#       4
#       5 # if license_plate_text is not None:
#
# ~\Documents\GitHub\imagpro_finals\format.py in read_license_plate(license_plate_crop)
#      75         for j in [0, 1, 2, 3, 4, 5, 6]:
#      76             if text[j] in mapping[j].keys():
# ---> 77                 license_plate_ += mapping[j][text[j]]
#      78             else:
#      79                 license_plate_ += text[j]
#
# NameError: name 'reader' is not defined

# %%
print(license_plate_text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26972\3537063275.py in <module>
# ----> 1 print(license_plate_text)
#
# NameError: name 'license_plate_text' is not defined
